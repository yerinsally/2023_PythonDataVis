# %% [markdown]
# #1. 파이썬 언어를 배우면서 편리하다고 생각되었던 내용을 아래에 작성하시오.

# %% [markdown]
# 답안: 파이썬은 다른 개발 언어보다 상당히 직관적이고 간결한 문법으로 구성되어 있다. 프로그래밍을 전공으로 하지 않아도 쉽게 파이썬 문법을 익히고 이를 활용할 수 있다. 또한 수많은 표준 라이브러리를 제공하기 때문에 모든 코드를 일일이 작성하지 않아도 된다.

# %% [markdown]
# #2. Colab은 클라우드 환경의 대표적인 사례라고 할 수 있다. Colab의 기능을 학습자의 관점에서 실제 사용하면서 이해하고 있는 내용을 작성하시오.

# %% [markdown]
# 답안: 파이썬을 사용하기 위해 개발환경을 설정할 필요가 없고, 거의 대부분의 라이브러리가 이미 설치되어 있다. 웹 브라우저 기반의 주피터 노트북을 제공하여 소스 코드를 문서화할 수 있다. 즉 웹에 접속하여 Google Drive에 Colab 파일을 만들면 누구나 파이썬 언어를 사용할 수 있다는 장점이 있다.

# %% [markdown]
# #아래 물음에 답하시오

# %% [markdown]
# ##3-1 Python 프로그램을 작성하여 사용 중인 Python 버전을 확인하는 코드를 작성하시오.

# %%
#아래에 답안을 작성하시오.

# !python -V
# Out:
# Python 3.9.16

# %% [markdown]
# ##3-2 다음 리스트의 첫 번째 색상과 마지막 색상을 표시하는 Python 프로그램을 작성하세요.
# *   color_list = ["Red","Green","White" ,"Black"]

# %%
#아래에 답안을 작성하시오.
color_list = ["Red","Green","White" ,"Black"]
print(color_list[0], color_list[3])
# Out:
# Red Black

# %% [markdown]
# ##3-3 color_list_2에 없는 color_list_1의 모든 색상을 출력하는 Python 프로그램을 작성하세요
# *   color_list_1 = set(["Banana", "Bean", "Apple"])
# *   color_list_2 = set(["Bean", "Orange"])
# *   Expected Output :
# {'Apple', 'Banana'}

# %%
#아래에 답안을 작성하시오.
color_list_1 = set(["Banana", "Bean", "Apple"])
color_list_2 = set(["Bean", "Orange"])
print('Expected Output:', color_list_1 - color_list_2)
# Out:
# Expected Output: {'Apple', 'Banana'}

# %% [markdown]
# ##3-4 주어진 문자열의 처음 2개 문자와 마지막 2개 문자로 구성된 문자열을 가져오는 Python 프로그램을 작성하시오.(단, 문자열의 길이가 2보다 작으면 빈 문자열을 반환함)

# %%
#아래에 답안을 작성하시오.
def fun(s):
    if len(s) < 2:
        return " "
    else:
        return s[:2] + s[-2:]
print(fun('hello'))
print(fun('python'))
print(fun('h'))
# Out:
# helo
# pyon

# %% [markdown]
# ##3-5 딕셔너리에서 키가 동일한 값을 합산하여 출력하는 Python 프로그램을 작성하시오.
# *   d1 = {'sook': 100, 'myung': 200, 'univ':300}
# *   d2 = {'sook': 300, 'myung': 200, 'women':400}
# *   Sample output: Counter({'sook': 400, 'myung': 400, 'women': 400, 'univ': 300})

# %%
#아래에 답안을 작성하시오.
d1 = {'sook': 100, 'myung': 200, 'univ':300}
d2 = {'sook': 300, 'myung': 200, 'women':400}
result = d2
temp = list(d1.keys())
for i in range(len(d1)):
  if temp[i] in result:
    result[temp[i]] += d1[temp[i]]
  else:
    result[temp[i]] = d1[temp[i]]
result
# Out:
# {'sook': 400, 'myung': 400, 'women': 400, 'univ': 300}

# %% [markdown]
# ##3-6. 5개의 정수 배열을 생성하고 배열 항목을 표시하는 Python 프로그램을 작성하시오. 그리고 인덱스를 통해 개별 요소를 억세스하는 코드를 추가하시오.

# %%
#아래에 답안을 작성하시오.
import numpy as np
import random
arr = [random.randint(1, 100) for i in range(5)]

for i in range(len(arr)):
  print("arr[", i, "] = ", arr[i])

# 개별 인덱스로 엑세스
print(arr[0], arr[1], arr[2], arr[3], arr[4])
# Out:
# arr[ 0 ] =  13
# arr[ 1 ] =  32
# arr[ 2 ] =  69
# arr[ 3 ] =  60
# arr[ 4 ] =  12
# 13 32 69 60 12

# %% [markdown]
# ##3-7 리스트의 모든 숫자를 합산하는 Python 함수를 작성하시오.
# *   Sample List : [8, 2, 3, 0, 7]
# *   Expected Output : 20

# %%
#아래에 답안을 작성하시오.
Sample_List = [8, 2, 3, 0, 7]
print('Expected Output:', sum(Sample_List))
# Out:
# Expected Output: 20

# %% [markdown]
# ##3-8 문자열을 받아서 대문자와 소문자의 수를 각각 세는 Python 함수를 작성하시오.
# *   Sample List : 'Sookmyung Women's University'
# *   Expected Output :
# *   No. of Upper case characters : 3
# *   No. of Lower case Characters : 22

# %%
Sample_List = "Sookmyung Women's University"
print('No. of Upper case characters:', sum(c.isupper() for c in Sample_List))
print('No. of Lower case characters:', sum(c.islower() for c in Sample_List))
# Out:
# No. of Upper case characters: 3
# No. of Lower case characters: 22

# %% [markdown]
# ##3-9 다음과 같은 배열을 얻도록 파이썬의 numpy 라이브러리를 이용하여 배열을 구성하시오.
# ![numpy1.png](data:image/png;base64,...)

# %%
#아래에 답안을 작성하시오.
#답X

# %% [markdown]
# ##3-10 두 개의 Pandas Series를 더하고, 빼고, 곱하고, 나누는 Pandas 프로그램을 작성하시오.
# *   Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 9]

# %%
import pandas as pd
index = ['a', 'b', 'c', 'd', 'e']
s1 = [2,4,6,8,10]
s2 = [1,3,5,7,9]
series1 = pd.Series(s1, index=index)
series2 = pd.Series(s2, index=index)

def fun(a,b):
  return series1+series2, series1-series2, series1*series2, series1/series2
fun(series1, series2)
# Out:
# (a     3
#  b     7
#  c    11
#  d    15
#  e    19
#  dtype: int64,
#  a    1
#  b    1
#  c    1
#  d    1
#  e    1
#  dtype: int64,
#  a     2
#  b    12
#  c    30
#  d    56
#  e    90
#  dtype: int64,
#  a    2.000000
#  b    1.333333
#  c    1.200000
#  d    1.142857
#  e    1.111111
#  dtype: float64)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #아래에 주어진 코드를 참조하여 다음 물음에 답하시오.

# %%
import pandas as pd
import numpy as np

exam_data  = exam_data = {'name': ['Kim', 'Park', 'Lee', 'Jung', 'Cho', 'Roh', 'Oh', 'Choi', 'Yoo', 'Jang'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(exam_data , index=labels)

# %% [markdown]
# ##4-1 주어진 DataFrame의 처음 3개 행을 가져오는 Pandas 프로그램을 작성하시오.

# %%
#아래에 답안을 작성하시오.

df.head(3)
# Out:
#    name  score  attempts qualify
# a   Kim   12.5         1     yes
# b  Park    9.0         3      no
# c   Lee   16.5         2     yes

# %% [markdown]
# ##4-2 'name' 및 'score' 열을 선택하는 Pandas 프로그램을 작성하시오.

# %%
#아래에 답안을 작성하시오.

df.loc[:,'name':'score']
# Out:
#    name  score
# a   Kim   12.5
# b  Park    9.0
# c   Lee   16.5
# d  Jung    NaN
# e   Cho    9.0
# f   Roh   20.0
# g    Oh   14.5
# h  Choi    NaN
# i   Yoo    8.0
# j  Jang   19.0

# %% [markdown]
# ##4-3 행 1, 3, 5, 6에서 'name' 과 'attempts' 열을 선택하는 코드를 작성하시오.

# %%
#아래에 답안을 작성하시오.

df.iloc[0:7:2,0:3:2]
# Out:
#   name  attempts
# a  Kim         1
# c  Lee         2
# e  Cho         2
# g   Oh         1

# %% [markdown]
# #5. pandas 라이브러리를 이용하여 cosmetics.csv 파일을 불러오기 위한 코드를 작성하시오.
# *   cosmetics.csv 파일은 스노우보드에서 다운로드받아 자신의 구글 드라이브의 아래 폴더에 업로드하세요.
#
# > My Drive/Colab Notebooks/python_visualization/data

# %%
#아래에 답안을 작성하시오.

from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/python_visualization/cosmetics_.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #6. 위 5번에서 데이터를 읽은 후 각 column별로 시각화 함수를 적용해보고 가장 적합한 함수를 찾아 시각화하고 아래에 코드를 작성하시오.

# %%
#아래에 답안을 작성하시오.
df
# Out:
#      gender  marriage  edu  job  mincome  aware  count   amount  decision  \
# 0         1         1    4    1        2      2      1    11000         2
# 1         2         1    4    9        2      1      4    30000         1
# 2         2         2    4    4        3      1      6   100000         3
# 3         2         2    4    7        5      2      6    65000         3
# 4         1         2    6    6        5      2      2    50000         2
# ..      ...       ...  ...  ...      ...    ...    ...      ...       ...
# 242       1         1    4    2        3      2      6     4000         1
# 243       2         2    4    4        2      1     10   150000         3
# 244       2         2    7    8        1      2      3   100000         1
# 245       1         1    4    6        1      3      2    20000         3
# 246       2         2    6   10        1      1     10  1000000         3
#
#      propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# ...

# %%
df.plot(subplots=True);

# %%
df.plot(grid=True);  # DataFrame 그래프

# %%
import matplotlib.pyplot as plt

plt.bar(df['gender'], df['amount'])
plt.title('cosmetic')
plt.show() # 그래프 출력

# %% [markdown]
# #7. 문자열을 받아들이고 대문자와 소문자의 수를 세는 Python 함수를 작성하시오.

# %%
#아래에 답안을 작성하시오.

#중복됨
